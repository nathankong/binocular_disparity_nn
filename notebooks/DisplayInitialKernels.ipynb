# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Gabor Initialization

# %%
k = np.load("../initial_kernels_gabor.npy")
print(k.shape)
# Out:
# (28, 2, 19, 19)

# %%
for i in range(k.shape[0]):
    kernels = k[i]
    fig, (ax1, ax2) = plt.subplots(1,2)
    ax1.imshow(kernels[0,:,:], cmap="gray")
    ax1.set_title("Left Kernel #{}".format(i+1))
    ax2.imshow(kernels[1,:,:], cmap="gray")
    ax2.set_title("Right Kernel #{}".format(i+1))
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# ## Xavier Initialization

# %%
k = np.load("../initial_kernels_xavier.npy")
print(k.shape)
# Out:
# (28, 2, 19, 19)

# %%
for i in range(k.shape[0]):
    kernels = k[i]
    fig, (ax1, ax2) = plt.subplots(1,2)
    ax1.imshow(kernels[0,:,:], cmap="gray")
    ax1.set_title("Left Kernel #{}".format(i+1))
    ax2.imshow(kernels[1,:,:], cmap="gray")
    ax2.set_title("Right Kernel #{}".format(i+1))
